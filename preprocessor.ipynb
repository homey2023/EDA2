# %%
import pandas as pd

# %%
incheon_prostitution= pd.read_csv('경찰청 인천광역시경찰청_경찰서별 성매매 단속 현황_20230327_utf.csv')

# %%
crime_per_region = pd.read_csv('경찰청_범죄 발생 지역별 통계_20151231_utf.csv')

# %%
sexcrime_per_region= pd.read_csv('여성가족부_성범죄자_지역별_통계.csv')

# %%
police_reports = pd.read_csv('112+신고+접수·처리+현황_20230417110107.csv')

# %%
incheon_prostitution.head()
# Out:
#      년도  인천청   중부  미추홀  남동   부평  서부   계양  강화   연수  삼산  논현
# 0  2004    3    7    2   4   11   5    2   0    0   0   0
# 1  2005   61   16    8  23   21   6    4   1    3   0   0
# 2  2006  781  208    8  23   13  11   17   2   30   0   0
# 3  2007  204   29   39  70   67  18   12   1   32   1   0
# 4  2008  815   35   56  30  329  22  100   0  330  41   0

# %%
incheon_prostitution.rename(columns = {'sum':'SUM'}, inplace = True)

# %%
ls = []
for index, row in incheon_prostitution.iterrows():
    sum = row['인천청'] +row['중부']+ row['미추홀']+row['남동']+row['부평']+row['서부']+row['계양']+row['강화']+row['연수'] +row['삼산']+ row ['논현']
    ls.append(sum)

incheon_prostitution['sum'] = ls

# %%
incheon_prostitution.head()
# Out:
#    YEAR  인천청   중부  미추홀  남동   부평  서부   계양  강화   연수  삼산  논현   SUM
# 0  2004    3    7    2   4   11   5    2   0    0   0   0    34
# 1  2005   61   16    8  23   21   6    4   1    3   0   0   143
# 2  2006  781  208    8  23   13  11   17   2   30   0   0  1093
# 3  2007  204   29   39  70   67  18   12   1   32   1   0   473
# 4  2008  815   35   56  30  329  22  100   0  330  41   0  1758

# %%
crime_per_region.head(50)
# Out:
#      범죄대분류      범죄중분류     서울     부산     대구     인천     광주     대전     울산    세종  \
# 0     강력범죄       살인기수     67     20     13     17     11      8     12     2
# 1     강력범죄      살인미수등     96     41     23     34      7     16     11     1
# 2     강력범죄         강도    274    161     60    103     44     64     29     0
# 3     강력범죄         강간    969    383    216    304    216    181    132     3
# 4     강력범죄       유사강간    118     24     21     35     17     14     10     1
# 5     강력범죄       강제추행   4282    991    645    924    495    362    293    34
# 6     강력범죄  기타강간강제추행등     94     37     20     31     22     12      9     0
# 7     강력범죄         방화    315    117     86     94     48     41     36     5
# 8     절도범죄         절도  55280  20136  12759  10679   8438   9495   5449   638
# 9     폭력범죄         상해   7174   4675   2736   2179   1162   1516   1353   117
# 10    폭력범죄         폭행  36904   8852   6607   9774   5386   4054   4213   139
# ...

# %%
print(crime_per_region.columns)
# Out:
# Index(['범죄대분류', '범죄중분류', '서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종',
#        '경기 고양', '경기 과천', '경기 광명', '경기 광주', '경기 구리', '경기 군포', '경기 김포', '경기 남양주',
#        '경기 동두천', '경기 부천', '경기 성남', '경기 수원', '경기 시흥', '경기 안산', '경기 안성', '경기 안양',
#        '경기 양주', '경기 여주', '경기 오산', '경기 용인', '경기 의왕', '경기 의정부', '경기 이천', '경기 파주',
#        '경기 평택', '경기 포천', '경기 하남', '경기 화성', '강원 강릉', '강원 동해', '강원 삼척', '강원 속초',
#        '강원 원주', '강원 춘천', '강원 태백', '충북 제천', '충북 청주', '충북 충주', '충남 계룡', '충남 공주',
#        '충남 논산', '충남 당진', '충남 보령', '충남 서산', '충남 아산', '충남 천안', '전북 군산', '전북 김제',
#        '전북 남원', '전북 익산', '전북 전주', '전북 정읍', '전남 광양', '전남 나주', '전남 목포', '전남 순천',
#        '전남 여수', '경북 경산', '경북 경주', '경북 구미', '경북 김천', '경북 문경', '경북 상주', '경북 안동',
#        '경북 영주', '경북 영천', '경북 포항', '경남 거제', '경남 김해', '경남 마산', '경남 밀양', '경남 사천',
#        '경남 양산', '경남 진주', '경남 창원', '경남 통영', '제주 서귀포', '제주 제주', '기타도시', '도시이외'],
#       dtype='object')

# %%
sexcrime_per_region.head(20)
# Out:
#          지역   통계
# 0       강원도  124
# 1       경기도  710
# 2      경상남도  229
# 3      경상북도  210
# 4     광주광역시  117
# 5        기타  560
# 6     대구광역시  139
# 7     대전광역시   80
# 8     부산광역시  179
# 9     서울특별시  421
# 10  세종특별자치시    8
# 11    울산광역시   55
# 12    인천광역시  232
# 13     전라남도  140
# 14     전라북도  186
# 15  제주특별자치도   42
# 16     충청남도  178
# 17     충청북도  143

# %%
import matplotlib.pyplot as plt

# %%
plt.bar()

# %%
police_reports.head(20)
# Out:
#           현황별(1)   현황별(2)     2010     2011     2012     2013     2014  \
# 0      112 신고 접수       소계  2687727  2841869  2795088  4705612  4411656
# 1      112 신고 접수     중요범죄    69493    50588    47278    82506    90503
# 2      112 신고 접수     기타범죄   468406   577845   691719   789306   848369
# 3      112 신고 접수     질서유지   948368   860436   804806   822312   822049
# 4      112 신고 접수     교  통   398633   376410   366833   384198   384713
# 5      112 신고 접수  기타경찰 업무   584241   737581   655535   803270   881491
# 6      112 신고 접수   타기관 기타   218586   239009   228917  1824020  1384531
# 7   범죄현장 평균 도착시간       평균    4분00초    3분07초    3분03초    3분24초    3분25초
# 8   범죄현장 평균 도착시간       긴급    3분56초    3분00초    3분00초    3분34초    3분21초
# 9   범죄현장 평균 도착시간      비긴급    4분01초    3분08초    3분04초    3분20초    3분26초
# 10     중요범죄 현장검거       소계    63370    47039     3233    50085     3291
# 11     중요범죄 현장검거       살인       11       12        5       21        8
# ...

# %%
incheon_prostitution
